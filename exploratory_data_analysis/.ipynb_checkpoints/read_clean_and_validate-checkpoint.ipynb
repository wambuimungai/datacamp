# %% [markdown]
# ## Read Clean & Validate

# %%
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt
import seaborn as sns
#from empiricaldist import Pmf, Cdf

file_path ='/Users/joycemungai/datacamp/exploratory_data_analysis/datasets/'

# %%
#nsfg data-National survey of family group
nsfg = pd.read_hdf(file_path + 'nsfg.hdf5', 'nsfg')

# %%
nsfg.head()
# Out:
#    caseid  outcome  birthwgt_lb1  birthwgt_oz1  prglngth  nbrnaliv  agecon  \
# 0   60418        1           5.0           4.0        40       1.0    2000
# 1   60418        1           4.0          12.0        36       1.0    2291
# 2   60418        1           5.0           4.0        36       1.0    3241
# 3   60419        6           NaN           NaN        33       NaN    3650
# 4   60420        1           8.0          13.0        41       1.0    2191
#
#    agepreg  hpagelb  wgt2013_2015
# 0   2075.0     22.0   3554.964843
# 1   2358.0     25.0   3554.964843
# 2   3308.0     52.0   3554.964843
# 3      NaN      NaN   2484.535358
# 4   2266.0     24.0   2903.782914

# %%
print(nsfg.shape)
print(nsfg.columns)
# Out:
# (9358, 10)
# Index(['caseid', 'outcome', 'birthwgt_lb1', 'birthwgt_oz1', 'prglngth',
#        'nbrnaliv', 'agecon', 'agepreg', 'hpagelb', 'wgt2013_2015'],
#       dtype='object')

# %% [markdown]
# #Outcome  Interpreted
# #1	Live birth
# #3	Stillbirth
# #4	Miscarriage
# #5	Ectopic pregnancy
# #6	Current pregnancy

# %%
#How many pregnancies in this dataset ended with a live birth?
nsfg['outcome'].value_counts()
# Out:
# 1    6489
# 4    1469
# 2     947
# 6     249
# 5     118
# 3      86
# Name: outcome, dtype: int64

# %%
#compute pregnancy length summary statistics 
agecon = nsfg['agecon']/100
agepreg = nsfg['agepreg']/100

preg_length = agepreg-agecon

preg_length.describe()
# Out:
# count    9109.000000
# mean        0.552069
# std         0.271479
# min         0.000000
# 25%         0.250000
# 50%         0.670000
# 75%         0.750000
# max         0.920000
# dtype: float64

# %%
#distribution  of number of pregancies by age at conception
plt.hist(agecon, bins=20, histtype='step')

plt.xlabel('Age at conception')
plt.ylabel('Number of pregnancies')

plt.show()

# %% [markdown]
# #### Cleaning data

# %%
nsfg['nbrnaliv'].value_counts()
# Out:
# 1.0    6379
# 2.0     100
# 3.0       5
# 8.0       1
# Name: nbrnaliv, dtype: int64

# %%
nsfg['nbrnaliv'].replace(8, np.nan, inplace=True)

# %%
 nsfg['birthwgt_lb1'].value_counts().sort_index()
# Out:
# 0.0        6
# 1.0       34
# 2.0       47
# 3.0       67
# 4.0      196
# 5.0      586
# 6.0     1666
# 7.0     2146
# 8.0     1168
# 9.0      363
# 10.0      82
# 11.0      17
# 12.0       7
# 13.0       2
# 14.0       2
# 17.0       1
# 98.0       1
# 99.0      94
# Name: birthwgt_lb1, dtype: int64

# %%
#compute the average birth weight for full-term babies.

#resample data
def resample_rows_weighted(df, column='wgt2013_2015'):
    """Resamples a DataFrame using probabilities proportional to given column.
    df: DataFrame
    column: string column name to use as weights
    returns: DataFrame
    """
    weights = df[column].copy()
    weights /= sum(weights)
    indices = np.random.choice(df.index, len(df), replace=True, p=weights)
    sample = df.loc[indices]
    return sample

# %%
nsfg = resample_rows_weighted(nsfg, 'wgt2013_2015')
nsfg.head()
# Out:
#       caseid  outcome  birthwgt_lb1  birthwgt_oz1  prglngth  nbrnaliv  agecon  \
# 5632   66478        1           5.0          13.0        40       1.0    2000
# 4418   65216        1           6.0           6.0        41       1.0    2366
# 1993   62521        2           NaN           NaN         4       NaN    1550
# 4256   65016        1           7.0           9.0        39       1.0    2291
# 7461   68565        1          99.0           NaN        39       1.0    3000
#
#       agepreg  hpagelb  wgt2013_2015
# 5632   2075.0     24.0   5062.163066
# 4418   2441.0     35.0  75399.410000
# 1993   1550.0      NaN  19683.092561
# 4256   2366.0     29.0  25262.125110
# 7461   3075.0     30.0   8062.903992

# %%
# Clean the weight variables
nsfg['birthwgt_lb1'].replace([98,99], np.nan, inplace=True) 
nsfg['birthwgt_oz1'].replace([98,99], np.nan, inplace=True) 

birth_weight = nsfg['birthwgt_lb1'] + nsfg['birthwgt_oz1']/16

# %%
sns.distplot(birth_weight)

# %%
full_term =nsfg['prglngth']>= 37
full_term_weight = birth_weight[full_term]
print(full_term_weight.mean())

pre_term_weight = birth_weight[~full_term]
print(pre_term_weight.mean())
# Out:
# 7.45662347012239
# 5.729396361631753

# %%
f, ax = plt.subplots(1, 2, figsize=(16,6), sharex=False)

sns.distplot(nsfg['prglngth'], ax=ax[0])
sns.distplot(nsfg['hpagelb'], ax=ax[1])

# %%
#compute full term weight for single vs multiple babies
single = nsfg['nbrnaliv'] == 1

single_ft_weight = birth_weight[full_term & single] 
print('mean single full term weight:' + str(single_ft_weight.mean()))

multi_ft_weight = birth_weight[full_term & ~single] 
print('mean multiple full term weight:' + str(multi_ft_weight.mean()))
# Out:
# mean single full term weight:7.46822878897752
# mean multiple full term weight:5.85625
